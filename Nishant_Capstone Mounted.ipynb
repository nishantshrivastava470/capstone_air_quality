# %%
# # Firstly mounting the container to ADB

# dbutils.fs.mount(
#    source="wasbs://capstone@nishantadlsstorage.blob.core.windows.net",
#    mount_point="/mnt/nishantadlsstorage",
#    extra_configs={
#        "fs.azure.account.key.nishantadlsstorage.blob.core.windows.net": dbutils.secrets.get(
#            scope="nishantadbscope_UnityCatalog", key="nishantsecretadls"
#        )
#    }
# )

# Already mounted hence commented

# %%
# To check if scope is availbale or not
dbutils.secrets.listScopes() # expecting "nishantadbscope"
